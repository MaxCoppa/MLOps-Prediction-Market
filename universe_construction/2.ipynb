# %%
import pandas as pd
from tqdm import tqdm

# %%
market_data = pd.read_parquet("market_data.parquet")

# %%
tickers = list(market_data.ticker.unique())
batch_size = int(10000/1000)
for i in tqdm(range(0, len(tickers), batch_size), desc="Fetching"):
    continue
# Out:
# Fetching: 100%|██████████| 27392/27392 [00:00<00:00, 4415633.77it/s]
